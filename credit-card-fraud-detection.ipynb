# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix

# %%
df=pd.read_csv("creditcard.csv")
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# #we dont have any missing value in dataset

# %% [markdown]
# **the dataset is highly unbalanced**

# %%
legit=df[df.Class==0]
fraud=df[df.Class==1]

# %%
legit
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
df.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
legit_sample=legit.sample(n=492)

# %%
credit_card=pd.concat([legit_sample,fraud])

# %%
credit_card.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 127780   78466.0 -0.837107  0.690799  1.612956  0.752783  0.585590 -0.818869
# 8755     11915.0  1.174587  0.011227  0.577763  0.194952 -0.451965 -0.410294
# 132445   79989.0 -1.472544  0.003286  1.682093 -0.430669  1.516078 -0.641678
# 10925    18741.0  1.206553 -0.205390  1.193460 -0.443671 -1.235657 -0.942281
# 284358  172374.0 -1.214723  0.014012  0.240210 -1.524412  2.418668  3.995453
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 127780  0.236658 -0.077510 -0.737947  ... -0.137892 -0.316544 -0.052599
# 8755   -0.315836 -0.001899  1.291363  ... -0.168317 -0.283905  0.099174
# 132445  0.081665  0.291535 -0.782525  ... -0.099461 -0.700336 -0.020806
# 10925  -0.591043 -0.181820  2.964621  ... -0.125863  0.146266 -0.002519
# 284358 -0.909077  1.276771  0.721634  ...  0.130386  0.628388  0.151352
#
# ...

# %%
credit_card["Class"].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
credit_card.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      93215.660569 -0.028726 -0.012598  0.119100  0.004725 -0.051107
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.054166  0.022122 -0.026379  0.012927  ...  0.021618 -0.027724
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.008178 -0.029366 -0.022307  0.008547 -0.000469  0.004547 -0.013202
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       95.603557
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
x=credit_card.drop("Class",axis=1)
y=credit_card["Class"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x.shape,x_train.shape,x_test.shape
# Out:
# ((984, 30), (787, 30), (197, 30))

# %%
model=LogisticRegression(max_iter=10000)
# sc=StandardScaler()
# x_train=sc.fit_transform(x_train)
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.8984771573604061

# %%
y_preds_test=model.predict(x_test)
y_preds_train=model.predict(x_train)
print(f"Accuracy score on training data is : {accuracy_score(y_train,y_preds_train)}")
print(f"Accuracy score on test data is : {accuracy_score(y_test,y_preds_test)}")
# Out:
# Accuracy score on training data is : 0.963151207115629
# Accuracy score on test data is : 0.8984771573604061

# %%
print(f"Precision score on test data is : {precision_score(y_test,y_preds_test)}")
# Out:
# Precision score on test data is : 0.9111111111111111

# %%
print(f" Recall score on test data is :{recall_score(y_test,y_preds_test)}")
# Out:
#  Recall score on test data is :0.8723404255319149

# %%
c_m=pd.DataFrame(confusion_matrix(y_test,y_preds_test))
c_m
# Out:
#     0   1
# 0  95   8
# 1  12  82

# %%
sns.heatmap(c_m,
            annot=True,
           cmap=["lightblue","yellow"],
           linewidths=1)
# Out:
# <Axes: >
